# %%
import numpy as np
import pandas as pd
from scipy import stats
from statsmodels.stats.proportion import proportions_ztest
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 1 จงทดสอบที่ระดับนัยสำคัญ 0.05 ว่า ข้อมูลจำนวนกระบอกสูบ (cyl) เป็นอิสระจากข้อมูลระบบเครื่องยนต์ (vs) หรือไม่

# %%
df = pd.read_csv("http://tinyurl.com/ProgStatMtcars")
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# **สมมติฐาน**:

# %% [markdown]
# H0:  ข้อมูลจำนวนกระบอกสูบ (cyl) และข้อมูลระบบเครื่องยนต์ (vs) ไม่มีความสัมพันธ์กัน (เป็นอิสระต่อกัน)
# H1: ข้อมูลจำนวนกระบอกสูบ (cyl) และข้อมูลระบบเครื่องยนต์ (vs) มีความสัมพันธ์กัน (ไม่เป็นอิสระต่อกัน)

# %% [markdown]
# **ค่า chi2_cal**:

# %%
 O = pd.crosstab(df.cyl, df.vs)
 O
# Out:
# vs    0   1
# cyl
# 4     1  10
# 6     3   4
# 8    14   0

# %%
chi2_cal, p_val, dof, E = stats.chi2_contingency(O, correction=False)
chi2_cal
# Out:
# 21.339929911358485

# %% [markdown]
# **ตาราง E**:

# %%
E
# Out:
# array([[6.1875, 4.8125],
#        [3.9375, 3.0625],
#        [7.875 , 6.125 ]])

# %% [markdown]
# **หาค่า chi2_crit:**

# %%
chi2_crit = stats.chi2.isf(0.05, df=dof)
chi2_crit
# Out:
# 5.991464547107983

# %% [markdown]
# **หาค่า p-val:**

# %%
p_val
# Out:
# 2.3232347637946903e-05

# %% [markdown]
# **สรุปผล:**

# %% [markdown]
# - chi2_cal ตกในบริเวณวิกฤต
# - p_val < 0.05
#
# ดังนั้นปฏิเสธ H0 ยอมรับ H1 ข้อมูลจำนวนกระบอกสูบ (cyl) และข้อมูลระบบเครื่องยนต์ (vs) มีความสัมพันธ์กัน (ไม่เป็นอิสระต่อกัน) ที่ระดับนัยสำคัญ 0.05

# %% [markdown]
# **กราฟแจกแจงความน่าจะเป็น:**
# <font color='red'>***เนื่องจากข้อนี้มี df ต่ำ=2 กราฟจึงมีลักษณะดังภาพ แต่นิสิตสามารถวาดเป็นกราฟเบ้ขวาธรรมดาได้***</font>

# %%
x = np.linspace(0,10,1000)
y = [stats.chi2.pdf(v, df=dof) for v in x]
chi2_critical_right = chi2_crit

plt.plot(x,y, color='g')
plt.fill_between(x[x>=chi2_critical_right],
                 stats.chi2.pdf(x[x>=chi2_critical_right], df=dof),
                 color='g'
                 )
plt.text(chi2_critical_right-2.5, 0, f"+{chi2_critical_right:.3f}", color='r')
plt.axvline(chi2_cal, ls=':', color='r')

# %% [markdown]
# <font color='red'>***นิสิตสามารถวาดแบบนี้***</font>

# %%
dof = 3
x = np.linspace(0,20,1000)
y = [stats.chi2.pdf(v, df=dof) for v in x]
chi2_critical_right = chi2_crit

plt.plot(x,y, color='g')
plt.fill_between(x[x>=chi2_critical_right],
                 stats.chi2.pdf(x[x>=chi2_critical_right], df=dof),
                 color='g'
                 )
plt.text(chi2_critical_right-2.5, 0, f"+{chi2_critical_right:.3f}", color='r')
plt.axvline(chi2_cal, ls=':', color='r')

# %% [markdown]
# \
# #### 2 จากชุดข้อมูล mtcars.csv  จงทดสอบว่าอัตราส่วนของรถที่มีจำนวนกระบอกสูบ 4, 6, และ 8  คือ 2:1:2 หรือไม่ที่ระดับนัยสำคัญ 0.1

# %% [markdown]
# **สมมติฐาน**:

# %% [markdown]
# H0:  อัตราส่วนของรถที่มีจำนวนกระบอกสูบ 4, 6, และ 8  เท่ากับ 2:1:2
# H1: อัตราส่วนของรถที่มีจำนวนกระบอกสูบ 4, 6, และ 8  ไม่เท่ากับ 2:1:2

# %% [markdown]
# **ค่า chi2_cal**:

# %%
df.cyl.value_counts().sort_index()
# Out:
# 4    11
# 6     7
# 8    14
# Name: cyl, dtype: int64

# %%
O = df.cyl.value_counts().sort_index()
#O = np.array([11,7,14])
p = np.array([2/5, 1/5, 2/5])
E = df.shape[0]*p
chi2_cal, p_val = stats.chisquare(f_obs=O,
                                 	 f_exp=E)
chi2_cal
# Out:
# 0.42187499999999994

# %% [markdown]
# **ตาราง E**:

# %%
E
# Out:
# array([12.8,  6.4, 12.8])

# %% [markdown]
# **หาค่า chi2_crit:**

# %%
chi2_crit = stats.chi2.isf(0.1, df = 3-1)
chi2_crit
# Out:
# 4.605170185988092

# %% [markdown]
# **หาค่า p-val:**

# %%
p_val
# Out:
# 0.8098246793420794

# %% [markdown]
# **สรุปผล:**

# %% [markdown]
# - chi2_cal ตกในบริเวณยอมรับ H0
# - p_val > 0.1
#
# ดังนั้นยอมรับ H0 อัตราส่วนของรถที่มีจำนวนกระบอกสูบ 4, 6, และ 8  เท่ากับ 2:1:2

# %% [markdown]
# **กราฟแจกแจงความน่าจะเป็น:**

# %%
x = np.linspace(0,15,1000)
y = [stats.chi2.pdf(v, df=dof) for v in x]
chi2_critical_right = chi2_crit

plt.plot(x,y, color='g')
plt.fill_between(x[x>=chi2_critical_right],
                 stats.chi2.pdf(x[x>=chi2_critical_right], df=dof),
                 color='g'
                 )
plt.text(chi2_critical_right-1.7, 0, f"+{chi2_critical_right:.3f}", color='r')
plt.axvline(chi2_cal, ls=':', color='r')

# %% [markdown]
# \
# #### 3 จากชุดข้อมูล mtcars.csv  จงหาค่าสัมประสิทธิ์สหสัมพันธ์ระหว่างแรงม้า (hp) และ ระยะทางที่รถวิ่งได้ในหน่วยไมล์โดยใช้น้ำมัน 1 แกลลอน (mpg)  และทดสอบว่า hp และ mpg มีความสัมพันธ์เชิงเส้นหรือไม่ ที่ระดับนัยสำคัญ 0.05
#
# กำหนดให้
# - ρ คือ สัมประสิทธิ์สหสัมพันธ์ระหว่าง hp และ mpg
# - ข้อมุล mpg  และ hp และ มีการแจกแจงแบบปกติ

# %% [markdown]
# **สมมติฐาน**:
# H0: ρ = 0
# H1: ρ ≠ 0

# %% [markdown]
# **ค่า r**:

# %%
r, p_val = stats.pearsonr(x=df.mpg, y=df.hp)
r
# Out:
# -0.7761683718265864

# %% [markdown]
# **ค่า t_cal**:

# %%
n = df.shape[0]
t_cal = r / np.sqrt((1-r**2)/(n-2))
t_cal
# Out:
# -6.74238854270679

# %% [markdown]
# **หาค่า t_crit:**

# %%
t_crit_left = stats.t.ppf(0.05/2, df=n-2)
t_crit_right = stats.t.isf(0.05/2, df=n-2)
t_crit_left, t_crit_right
# Out:
# (-2.042272456301238, 2.042272456301238)

# %% [markdown]
# **หาค่า p-val:**

# %%
p_val
# Out:
# 1.7878352541210677e-07

# %% [markdown]
# **สรุปผล:**

# %% [markdown]
# - t_cal ตกในบริเวณวิกฤต
# - p_val < 0.05
#
# ดังนั้นปฏิเสธ H0 ยอมรับ H1 ρ ≠ 0 hp และ mpg มีความสัมพันธ์เชิงเส้นที่ระดับนัยสำคัญ 0.05

# %% [markdown]
# **กราฟแจกแจงความน่าจะเป็น:**

# %%
x = np.linspace(-10,10,1000)
y = [stats.t.pdf(v, df=n-2) for v in x]

t_critical_left = t_crit_left
t_critical_right = t_crit_right

plt.plot(x,y, color='g')
plt.fill_between(x[x>=t_critical_right],
                 stats.t.pdf(x[x>=t_critical_right], df=n-2),
                 color='g'
                 )
plt.fill_between(x[x<=t_critical_left],
                 stats.t.pdf(x[x<=t_critical_left], df=n-2),
                 color='g'
                 )
plt.text(t_critical_left, 0, f"-{t_critical_left:.3f}", color='r')
plt.text(t_critical_right-0.7, 0, f"+{t_critical_right:.3f}", color='r')
plt.axvline(t_cal, ls=':', color='r')
